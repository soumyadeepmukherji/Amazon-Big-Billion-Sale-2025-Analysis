# %%
#Import Pandas
import pandas as pd

# %%
mobile_df = pd.read_csv('Amazon Big Billion Sale 2025 -Oct Mobile Phones.csv')

# %%
mobile_df
# Out:
#                                            Product_Name    Price  Rating  \
# 0     Samsung Galaxy M05 (Mint Green, 4GB RAM, 64 GB...   6249.0     4.0
# 1     Samsung Galaxy M06 5G (Sage Green, 6GB RAM, 12...   8999.0     3.9
# 2     realme C73 5G Smartphone 6.67 Inch Screen 120H...  10544.0     NaN
# 3     Redmi 13 5G Prime Edition, Orchid Pink, 8GB+12...  10999.0     4.1
# 4     Redmi A4 5G (Starry Black, 6GB RAM, 128GB Stor...   8999.0     3.9
# ...                                                 ...      ...     ...
# 3524  SupCares TPU Unbreakable Membrane Screen Prote...    365.0     3.7
# 3525  TheGiftKart Flip Cover Back Case for Motorola ...    299.0     4.1
# 3526  Gotrippin by Destinio Universal Travel Adapter...   1199.0     4.3
# 3527  TheGiftKart Flip Cover Back Case for Motorola ...    299.0     4.1
# 3528  Gotrippin by Destinio Universal Travel Adapter...   1199.0     4.3
#
#       Review_Count        ASIN  \
# 0             7230  B0DFY3XCB6
# ...

# %%
#View basic information about columns, rows & dataframe
mobile_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3529 entries, 0 to 3528
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_Name  3529 non-null   object
#  1   Price         3510 non-null   float64
#  2   Rating        3452 non-null   float64
#  3   Review_Count  3529 non-null   int64
#  4   ASIN          3529 non-null   object
#  5   Product_URL   3529 non-null   object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 165.6+ KB

# %%
#View statistical information
mobile_df.describe()
# Out:
#                Price       Rating   Review_Count
# count    3510.000000  3452.000000    3529.000000
# mean     4822.943020     4.053331    2444.121564
# std     15903.119484     0.403114   12263.929766
# min        39.000000     1.000000       0.000000
# 25%       199.000000     3.900000      46.000000
# 50%       299.000000     4.100000     233.000000
# 75%      1199.000000     4.300000    1018.000000
# max    179999.000000     5.000000  426987.000000

# %%
#view the list of columns
mobile_df.columns
# Out:
# Index(['Product_Name', 'Price', 'Rating', 'Review_Count', 'ASIN',
#        'Product_URL'],
#       dtype='object')

# %%
#View the number of rows and columns
mobile_df.shape
# Out:
# (3529, 6)

# %%
#Retrieving Data using column name
mobile_df['Review_Count']
# Out:
# 0       7230
# 1       3321
# 2          0
# 3       2379
# 4       7208
#         ...
# 3524     375
# 3525      85
# 3526    4356
# 3527      85
# 3528    4356
# Name: Review_Count, Length: 3529, dtype: int64

# %%
#Retrieve a specific value using indexing
mobile_df['Review_Count'][4]
# Out:
# 7208

# %%
#Retrieving value from Multiple columns
df = mobile_df[['Review_Count','Price']]
df
# Out:
#       Review_Count    Price
# 0             7230   6249.0
# 1             3321   8999.0
# 2                0  10544.0
# 3             2379  10999.0
# 4             7208   8999.0
# ...            ...      ...
# 3524           375    365.0
# 3525            85    299.0
# 3526          4356   1199.0
# 3527            85    299.0
# 3528          4356   1199.0
#
# [3529 rows x 2 columns]

# %%
#Retieving values using rows
mobile_df.loc[3524]
# Out:
# Product_Name    SupCares TPU Unbreakable Membrane Screen Prote...
# Price                                                       365.0
# Rating                                                        3.7
# Review_Count                                                  375
# ASIN                                                   B0DLBBJ5WP
# Product_URL     https://www.amazon.in/SupCares-Unbreakable-Pro...
# Name: 3524, dtype: object

# %%
#Retrieving multiple rows
#From First
mobile_df.head(5)

#From End
mobile_df.tail(5)

#Random
mobile_df.sample(5)
# Out:
#                                            Product_Name    Price  Rating  \
# 2     realme C73 5G Smartphone 6.67 Inch Screen 120H...  10544.0     NaN
# 3205  [Original] 45W Super Fast Charger Adapter Comp...    599.0     3.7
# 1997  SHINESTAR Redmi 12C / Poco C55 Flip Back Cover...    174.0     3.9
# 1895  FINGERS Mini MOT (My-Own-TV) Portable Speaker-...    850.0     4.2
# 2271  amazon basics Back Case Cover for Samsung Gala...     49.0     2.5
#
#       Review_Count        ASIN  \
# 2                0  B0FLV2S332
# 3205         10749  B0DJJZ8XL7
# 1997           322  B0BYBL196S
# 1895            26  B0CP59634B
# 2271             2  B0CZT3RYX1
#
#                                             Product_URL
# 2     https://www.amazon.in/realme-Smartphone-6000mA...
# 3205  https://www.amazon.in/Charger-Adapter-Compatib...
# 1997  https://www.amazon.in/SHINESTAR-Cover-Leather-...
# 1895  https://www.amazon.in/FINGERS-My-Own-TV-Speake...
# ...

# %%
#Sorting Values
mobile_df.sort_values('Price')
# Out:
#                                            Product_Name  Price  Rating  \
# 1968  Amazon Brand - Solimo Mobile Cover for Itel P5...   39.0     NaN
# 1978  Amazon Brand - Solimo Mobile Cover for Itel P5...   39.0     NaN
# 2277  amazon basics Back Case Cover for Samsung Gala...   49.0     2.5
# 2271  amazon basics Back Case Cover for Samsung Gala...   49.0     2.5
# 3475  Inefable® Pubg Anti-Slip Thumb Sleeve, Increas...   50.0     3.6
# ...                                                 ...    ...     ...
# 777   Vivo Y39 5G (Lotus Purple, 8GB RAM, 128GB Stor...    NaN     4.3
# 913   vivo Y100A 5G (Twilight Gold, 8GB RAM, 128GB S...    NaN     4.2
# 2148  ZEBRONICS FROSTFLO 10 Ultralight Mobile Cooler...    NaN     3.7
# 3501  Sony MDR-EX14AP Wired in Ear Headphone with Mi...    NaN     3.7
# 3513  Sony MDR-EX14AP Wired in Ear Headphone with Mi...    NaN     3.7
#
#       Review_Count        ASIN  \
# 1968             0  B0D3995G1C
# 1978             0  B0D3995G1C
# ...

# %%
#Add the values
mobile_df.Price.sum()
# Out:
# 16928530.0

# %%
#Query for sorting value using conditions
mobile_df[mobile_df.Price < 1000]
# Out:
#                                            Product_Name  Price  Rating  \
# 152   JioBharat V4 4G Phone with JioTV, JioHotstar, ...  799.0     3.3
# 158   Lava A1 Music(White), Bluetooth Support, Smart...  989.0     3.9
# 177   Lava A1 Clear Copper Keypad Mobile Phone with ...  749.0     3.9
# 195   JioBharat V4 4G Phone with JioTV, JioHotstar, ...  799.0     3.3
# 242   Lava A1 Josh (with BOL Feature) Dual Sim Keypa...  919.0     3.8
# ...                                                 ...    ...     ...
# 3522  A rtistque Back Cover Case for Xiaomi Mi 11 Li...  186.0     3.8
# 3523  Fashionury Back Cover for XiaoMi Redmi Note 10...  159.0     3.7
# 3524  SupCares TPU Unbreakable Membrane Screen Prote...  365.0     3.7
# 3525  TheGiftKart Flip Cover Back Case for Motorola ...  299.0     4.1
# 3527  TheGiftKart Flip Cover Back Case for Motorola ...  299.0     4.1
#
#       Review_Count        ASIN  \
# 152            745  B0DJMLYWFG
# 158            608  B0FLXGVY2D
# ...

# %%
#Adding new Column for Total number of reviews multiply with price
mobile_df['Total']= mobile_df.Price * mobile_df.Review_Count

mobile_df
# Out:
#                                            Product_Name    Price  Rating  \
# 0     Samsung Galaxy M05 (Mint Green, 4GB RAM, 64 GB...   6249.0     4.0
# 1     Samsung Galaxy M06 5G (Sage Green, 6GB RAM, 12...   8999.0     3.9
# 2     realme C73 5G Smartphone 6.67 Inch Screen 120H...  10544.0     NaN
# 3     Redmi 13 5G Prime Edition, Orchid Pink, 8GB+12...  10999.0     4.1
# 4     Redmi A4 5G (Starry Black, 6GB RAM, 128GB Stor...   8999.0     3.9
# ...                                                 ...      ...     ...
# 3524  SupCares TPU Unbreakable Membrane Screen Prote...    365.0     3.7
# 3525  TheGiftKart Flip Cover Back Case for Motorola ...    299.0     4.1
# 3526  Gotrippin by Destinio Universal Travel Adapter...   1199.0     4.3
# 3527  TheGiftKart Flip Cover Back Case for Motorola ...    299.0     4.1
# 3528  Gotrippin by Destinio Universal Travel Adapter...   1199.0     4.3
#
#       Review_Count        ASIN  \
# 0             7230  B0DFY3XCB6
# ...

# %%
#Adding rating on column number 2 comparing with other two rating avg
mobile_df.at[2,'Rating'] = (mobile_df.at[1,'Rating'] + mobile_df.at[3,'Rating'])/2

mobile_df.loc[2]
# Out:
# Product_Name    realme C73 5G Smartphone 6.67 Inch Screen 120H...
# Price                                                     10544.0
# Rating                                                        4.0
# Review_Count                                                    0
# ASIN                                                   B0FLV2S332
# Product_URL     https://www.amazon.in/realme-Smartphone-6000mA...
# Total                                                         0.0
# Name: 2, dtype: object

# %%
#Remove Column From the Dataframe
mobile_df.drop('Total', axis=1)
# Out:
#                                            Product_Name    Price  Rating  \
# 0     Samsung Galaxy M05 (Mint Green, 4GB RAM, 64 GB...   6249.0     4.0
# 1     Samsung Galaxy M06 5G (Sage Green, 6GB RAM, 12...   8999.0     3.9
# 2     realme C73 5G Smartphone 6.67 Inch Screen 120H...  10544.0     4.0
# 3     Redmi 13 5G Prime Edition, Orchid Pink, 8GB+12...  10999.0     4.1
# 4     Redmi A4 5G (Starry Black, 6GB RAM, 128GB Stor...   8999.0     3.9
# ...                                                 ...      ...     ...
# 3524  SupCares TPU Unbreakable Membrane Screen Prote...    365.0     3.7
# 3525  TheGiftKart Flip Cover Back Case for Motorola ...    299.0     4.1
# 3526  Gotrippin by Destinio Universal Travel Adapter...   1199.0     4.3
# 3527  TheGiftKart Flip Cover Back Case for Motorola ...    299.0     4.1
# 3528  Gotrippin by Destinio Universal Travel Adapter...   1199.0     4.3
#
#       Review_Count        ASIN  \
# 0             7230  B0DFY3XCB6
# ...
